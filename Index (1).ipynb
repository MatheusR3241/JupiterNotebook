# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Matheus Cerqueira dos Reis**
#
# Data Scientist

# %% [markdown]
# *Eu estou interessado em ciência de dados porque eu penso que esta área é muito promissora e interessante*

# %% [markdown]
#  ### Meu código irá efetuar uma soma

# %%
1+1
# Out:
# 2

# %% [markdown]
# | Título  | Título   |
# | ------- | -------- |
# | Texto   | Texto    |
# | Texto   | Texto    |
#
# [Link text Here](http://portal.stf.jus.br/noticias/verNoticiaDetalhe.asp?idConteudo=482484&ori=1)
#
# ~~finalizado~~
